# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\91982 /.deepface created
# Directory  C:\Users\91982 /.deepface/weights created

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread(r'C:\Users\91982\Pictures\Saved Pictures\NarendraModi.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
from pathlib import Path
home = str(Path.home())
print("HOME_FOLDER is ",home)
# Out:
# HOME_FOLDER is  C:\Users\91982

# %%
result = DeepFace.analyze(img1, actions = ['emotion'])

# %%
print(result)
# Out:
# {'region': {'x': 0, 'y': 0, 'w': 160, 'h': 125}, 'emotion': {'angry': 0.017143374134320766, 'disgust': 2.912979413238759e-07, 'fear': 0.7649448234587908, 'happy': 99.20036196708679, 'sad': 0.014355291204992682, 'surprise': 0.00207224929908989, 'neutral': 0.0011214537153136916}, 'dominant_emotion': 'happy'}
